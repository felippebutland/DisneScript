# %%
import re

REGEX = {
    'TYPES_DEFIN': r'\b(NUM|VIRNUM|PAL|SIMNAO)\b',
    # 'FUNCS_COND': r'\b(REP|DUVIDA|ENQ)\b',
    'REP': r'\b(REP)\b',
    'ENQ': r'\b(ENQ)\b',
    'DUVIDA': r'\b(DUVIDA)\b',
    'IMPRIMIR': r'\b(IMPRIMIR)\b',
    'FUNCS_CAST': r'\b(PARAPAL|PARANUM|PARAVIRNUM|PARASIMNAO)\b',
    
    'OPER_COND': r'(\>\=|\<\=|\!\=|\=|\<|\>)',
    'OPER_ARIT': r'(\+|\-|\*|\/)',
    'OPER_LOGIC': r'(\~|\^|\ˆ)',
    'OPER_DEFIN': r'¬\s*\bISTOEH\b',

    'ID': r'\b[a-zA-Z_][a-zA-Z0-9_]*\b',

    'VIRNUM': r'[0-9][0-9]*,[0-9][0-9]*',
    'NUM': r'[0-9][0-9]*',
    'PAL': r'(\'[^\']*\'|\"[^\"]*\")',
    'SIMNAO': r'(\bSIM\b|\bNAO\b)',
    ',': r'\,',
    ';': r'\;',
    ':': r'\:',
    '(': r'\(',
    ')': r'\)',
    '«': r'\«',
    '»': r'\»'
}

def tokenize(code):
    tokens = []
    position = 0
    code = re.sub(r"\s+", " ", code.replace('\n', ' ').replace('\t', ' '))
    while position < len(code):
        matched = False

        for token_name, pattern in REGEX.items():
            match = re.match(pattern, code[position:])

            if match:
                value = match.group(0)
                tokens.append({'token': token_name, 'value': value, 'position': position})
                position += len(value)
                matched = True
                break

        if not matched:
            position += 1  

    tokens.append({'token': '$', 'value': '$', 'position': len(code)+1})
    return tokens

# %% [markdown]
# # ANALISE SINTÁTICA

# %%
syntax_table = {
    'MAIN': {
        'ID': ['ID', 'DECL', 'MAIN'],
        'ENQ': ['FUNCS_COND', 'MAIN'],
        'REP': ['FUNCS_COND', 'MAIN'],
        'DUVIDA': ['FUNCS_COND', 'MAIN'],
        'PARANUM': ['FUNCS_CAST', 'MAIN'],
        'PARAVIRNUM': ['FUNCS_CAST', 'MAIN'],
        'PARASIMNAO': ['FUNCS_CAST', 'MAIN'],
        'PARANUM': ['FUNCS_CAST', 'MAIN'],
        'IMPRIMIR': ['IMPRIMIR', '(', 'VALUE', 'MULTIPLE_PARAM', ')', ';', 'MAIN'],
        'ε': [],
    },
    'DECL': {
        'OPER_DEFIN': ['OPER_DEFIN', 'TYPES_DEFIN', 'ATRIB', ';'],
        ':': ['ATRIB', ';'],
    },
    'ATRIB': {
        ':': [':', 'VALUE']
    },
    'FUNCS_COND': {
        'DUVIDA': ['DUVIDA', '(', 'COND', ')', '«', 'MAIN', '»'],
        'REP': ['REP', '(', 'COND', ')', '«', 'MAIN', '»'],
        'ENQ': ['ENQ', '(', 'COND', ')', '«', 'MAIN', '»']
    },

    'COND': {
        'ID': ['VALUE', 'OPER_COND', 'VALUE', 'MULTIPLE_COND'],
        'NUM': ['VALUE', 'OPER_COND', 'VALUE', 'MULTIPLE_COND'],
        'VIRNUM': ['VALUE', 'OPER_COND', 'VALUE', 'MULTIPLE_COND'],
        'PAL': ['VALUE', 'OPER_COND', 'VALUE', 'MULTIPLE_COND'],
        'SIMNAO': ['VALUE', 'OPER_COND', 'VALUE', 'MULTIPLE_COND'],
        'ε': []
    },
    'VALUE': {
        'ID': ['ID', 'MULTIPLE_ARIT'],
        'NUM': ['NUM', 'MULTIPLE_ARIT'],
        'VIRNUM': ['VIRNUM', 'MULTIPLE_ARIT'],
        'PAL': ['PAL', 'MULTIPLE_ARIT'],
        'SIMNAO': ['SIMNAO', 'MULTIPLE_ARIT'],
        'FUNCS_CAST':['FUNCS_CAST', '(', 'VALUE', ')'],
        '(': ['FUNC']
    },
    'FUNC': {
        '(': ['(', 'VALUE', 'MULTIPLE_PARAM', ')', '«', 'MAIN', '»']
    },
    'OPER_COND': {
        '>': ['>'],
        '<': ['<'],
        '>=': ['>='],
        '<=': ['<='],
        '=': ['='],
    },
    'OPER_LOGIC': {
        'ˆ': ['ˆ'],
        '^': ['^'],
        '~': ['~'],
        'ε': []
    },
    'OPER_ARIT': {
        '+': ['+'],
        '-': ['-'],
        '*': ['*'],
        '/': ['/'],
        'ε': []
    },
    'MULTIPLE_ARIT': {
        'OPER_ARIT': ['OPER_ARIT', 'VALUE', 'MULTIPLE_ARIT'],
        'ε': []
    },
    'MULTIPLE_COND': {
        'OPER_LOGIC': ['OPER_LOGIC', 'COND', 'MULTIPLE_COND'], # PARA CONDICOES MULTIPLAS
        'ε': []
    },
    'MULTIPLE_PARAM': {
        ',': [',', 'VALUE', 'MULTIPLE_PARAM'], #PARA FUNCOES COM MULTIPLOS PARAMETROS
        'ε': []
    }
}


def syntax_analyzer(token_list):
    stack = ['$', 'MAIN']  # Initialize the stack with the start symbol
    index = 0  
    
    while len(stack) > 0 or len(token_list) < index:
        current_symbol = stack[-1]
        current_token = token_list[index]
        print('Pilha:', stack, "\nSimbolo atual:", current_symbol,"\nSimbolo recebido: ", current_token['token'], "Valor: ", current_token['value'], "Posicao:", current_token['position'], "\n" )
       
        if current_symbol == current_token['token']:
            print("Encontrou o simbolo!")
            stack.pop()
            index += 1
       
        elif current_symbol in syntax_table:
            # print(current_token['token'],  syntax_table[current_symbol])
            if current_token['token'] in syntax_table[current_symbol]:
                production = syntax_table[current_symbol][current_token['token']]
                stack.pop()
                for symbol in reversed(production):
                    print("Adicionada a Pilha:", stack)
                    stack.append(symbol)
            else:
                if 'ε' in syntax_table[current_symbol]:
                    print("Caiu em Epson, recuperação\n")
                    stack.pop()
                else:
                    print("Error: Unexpected token", current_token['value'], "Position: ", current_token['position'])
                    return False
        else:
            print("Error: Invalid symbol in the stack", current_symbol)
            return False

    if len(stack) == 0:
        print("\n\nEste código é valido!")
        return True
    else:
        print("Error: Syntax analysis failed.")
        return False

# %%
if __name__ == '__main__':
    file = './dml_language.disney'
    # with open(file, 'rb') as f:
    #     code = f.read().decode('utf-8')

    code = '''
        val1 ¬ ISTOEH NUM : 100;

        qtd ¬ ISTOEH NUM: 12;
        qtd2 ¬ ISTOEH NUM: 14;
        qtd3 ¬ ISTOEH VIRNUM: 12,5;
        qtd4 ¬ ISTOEH NUM: 12;
        qtd5 ¬ ISTOEH NUM: 12;
        qtd6 ¬ ISTOEH NUM: "12";

        ENQ (qtd >= 0) «

            func: (qtd1) «
                qtd: "Errou";
            »;

            DUVIDA ( val1 < 0 ^ val1 / qtd+1 > 0) «
                val1: val1 * qtd * 1;
                qtd: qtd - 1;
            »
            DUVIDA ( val1 = 0 + PARANUM(5) ) «
                qtd: "Errou";
            »
            DUVIDA (val1 > 0 ) «
                val1: PARAVIRNUM(val1/qtd);
                qtd: qtd - 1;
            »

            IMPRIMIR("QTD", qtd, "val1', val1);
        »
        
    '''

    tokens = tokenize(code)
    syntax_analyzer(tokens)
    # for token in tokens:
    #     print(f"Token: {token['token']}, Value: {token['value']}, Position: {token['position']}")
# Out:
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  val1 Posicao: 1
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 1
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 6
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 6
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 15
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 19
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 19
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  100 Posicao: 21
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  100 Posicao: 21
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 24
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 24
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd Posicao: 26
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 26
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 30
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 30
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 39
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 42
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 42
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  12 Posicao: 44
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  12 Posicao: 44
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 46
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 46
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd2 Posicao: 48
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd2 Posicao: 48
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 53
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 53
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 62
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 65
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 65
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  14 Posicao: 67
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  14 Posicao: 67
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 69
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 69
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd3 Posicao: 71
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd3 Posicao: 71
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 76
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 76
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  VIRNUM Posicao: 85
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 91
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 91
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  VIRNUM Valor:  12,5 Posicao: 93
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'VIRNUM']
# Simbolo atual: VIRNUM
# Simbolo recebido:  VIRNUM Valor:  12,5 Posicao: 93
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 97
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 97
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd4 Posicao: 99
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd4 Posicao: 99
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 104
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 104
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 113
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 116
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 116
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  12 Posicao: 118
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  12 Posicao: 118
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 120
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 120
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd5 Posicao: 122
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd5 Posicao: 122
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 127
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 127
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 136
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 139
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 139
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  12 Posicao: 141
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  12 Posicao: 141
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 143
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 143
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd6 Posicao: 145
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd6 Posicao: 145
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 150
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN', 'OPER_DEFIN']
# Simbolo atual: OPER_DEFIN
# Simbolo recebido:  OPER_DEFIN Valor:  ¬ ISTOEH Posicao: 150
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB', 'TYPES_DEFIN']
# Simbolo atual: TYPES_DEFIN
# Simbolo recebido:  TYPES_DEFIN Valor:  NUM Posicao: 159
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 162
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 162
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  PAL Valor:  "12" Posicao: 164
#
# Adicionada a Pilha: ['$', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT', 'PAL']
# Simbolo atual: PAL
# Simbolo recebido:  PAL Valor:  "12" Posicao: 164
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 168
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 168
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ENQ Valor:  ENQ Posicao: 170
#
# Adicionada a Pilha: ['$']
# Adicionada a Pilha: ['$', 'MAIN']
# Pilha: ['$', 'MAIN', 'FUNCS_COND']
# Simbolo atual: FUNCS_COND
# Simbolo recebido:  ENQ Valor:  ENQ Posicao: 170
#
# Adicionada a Pilha: ['$', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(', 'ENQ']
# Simbolo atual: ENQ
# Simbolo recebido:  ENQ Valor:  ENQ Posicao: 170
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 174
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Simbolo atual: COND
# Simbolo recebido:  ID Valor:  qtd Posicao: 175
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 175
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 175
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  >= Posicao: 179
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Simbolo atual: OPER_COND
# Simbolo recebido:  OPER_COND Valor:  >= Posicao: 179
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  0 Posicao: 182
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  0 Posicao: 182
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 183
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  ) Valor:  ) Posicao: 183
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 183
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '«']
# Simbolo atual: «
# Simbolo recebido:  « Valor:  « Posicao: 185
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  func Posicao: 187
#
# Adicionada a Pilha: ['$', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  func Posicao: 187
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 191
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 191
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 191
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ( Valor:  ( Posicao: 193
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', 'FUNC']
# Simbolo atual: FUNC
# Simbolo recebido:  ( Valor:  ( Posicao: 193
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'VALUE', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 193
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd1 Posicao: 194
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd1 Posicao: 194
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 198
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')', 'MULTIPLE_PARAM']
# Simbolo atual: MULTIPLE_PARAM
# Simbolo recebido:  ) Valor:  ) Posicao: 198
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 198
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', '«']
# Simbolo atual: «
# Simbolo recebido:  « Valor:  « Posicao: 200
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd Posicao: 202
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 202
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 205
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 205
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 205
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  PAL Valor:  "Errou" Posicao: 207
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'PAL']
# Simbolo atual: PAL
# Simbolo recebido:  PAL Valor:  "Errou" Posicao: 207
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 214
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 214
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  » Valor:  » Posicao: 216
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', '»']
# Simbolo atual: »
# Simbolo recebido:  » Valor:  » Posicao: 216
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 217
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 219
#
# Adicionada a Pilha: ['$', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Pilha: ['$', 'MAIN', '»', 'MAIN', 'FUNCS_COND']
# Simbolo atual: FUNCS_COND
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 219
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(', 'DUVIDA']
# Simbolo atual: DUVIDA
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 219
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 226
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Simbolo atual: COND
# Simbolo recebido:  ID Valor:  val1 Posicao: 228
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 228
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 228
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  < Posicao: 233
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Simbolo atual: OPER_COND
# Simbolo recebido:  OPER_COND Valor:  < Posicao: 233
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  0 Posicao: 235
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  0 Posicao: 235
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_LOGIC Valor:  ^ Posicao: 237
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  OPER_LOGIC Valor:  ^ Posicao: 237
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'COND']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'COND', 'OPER_LOGIC']
# Simbolo atual: OPER_LOGIC
# Simbolo recebido:  OPER_LOGIC Valor:  ^ Posicao: 237
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'COND']
# Simbolo atual: COND
# Simbolo recebido:  ID Valor:  val1 Posicao: 239
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 239
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 239
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  / Posicao: 244
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  / Posicao: 244
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 246
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 246
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  + Posicao: 249
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  + Posicao: 249
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  1 Posicao: 250
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  1 Posicao: 250
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 252
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 252
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 252
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Simbolo atual: OPER_COND
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 252
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  0 Posicao: 254
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  0 Posicao: 254
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 255
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  ) Valor:  ) Posicao: 255
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  ) Valor:  ) Posicao: 255
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 255
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«']
# Simbolo atual: «
# Simbolo recebido:  « Valor:  « Posicao: 257
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  val1 Posicao: 259
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 259
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 263
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 263
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 263
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 265
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 265
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  * Posicao: 270
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  * Posicao: 270
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 272
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 272
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  * Posicao: 276
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  * Posicao: 276
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  1 Posicao: 278
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  1 Posicao: 278
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 279
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 279
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 279
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 279
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd Posicao: 281
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 281
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 284
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 284
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 284
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 286
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 286
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  - Posicao: 290
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  - Posicao: 290
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  1 Posicao: 292
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  1 Posicao: 292
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 293
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 293
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 293
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  » Valor:  » Posicao: 295
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Simbolo atual: »
# Simbolo recebido:  » Valor:  » Posicao: 295
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 297
#
# Adicionada a Pilha: ['$', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Pilha: ['$', 'MAIN', '»', 'MAIN', 'FUNCS_COND']
# Simbolo atual: FUNCS_COND
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 297
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(', 'DUVIDA']
# Simbolo atual: DUVIDA
# Simbolo recebido:  DUVIDA Valor:  DUVIDA Posicao: 297
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 304
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'COND']
# Simbolo atual: COND
# Simbolo recebido:  ID Valor:  val1 Posicao: 306
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 306
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 306
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  = Posicao: 311
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Simbolo atual: OPER_COND
# Simbolo recebido:  OPER_COND Valor:  = Posicao: 311
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  0 Posicao: 313
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  0 Posicao: 313
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  + Posicao: 315
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  + Posicao: 315
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  FUNCS_CAST Valor:  PARANUM Posicao: 317
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'VALUE', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'VALUE', '(', 'FUNCS_CAST']
# Simbolo atual: FUNCS_CAST
# Simbolo recebido:  FUNCS_CAST Valor:  PARANUM Posicao: 317
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'VALUE', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 324
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  5 Posicao: 325
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  5 Posicao: 325
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 326
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 326
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 328
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  ) Valor:  ) Posicao: 328
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 328
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«']
# Simbolo atual: «
# Simbolo recebido:  « Valor:  « Posicao: 330
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# ...
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 356
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 356
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 361
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE', 'OPER_COND']
# Simbolo atual: OPER_COND
# Simbolo recebido:  OPER_COND Valor:  > Posicao: 361
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  0 Posicao: 363
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  0 Posicao: 363
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 365
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')', 'MULTIPLE_COND']
# Simbolo atual: MULTIPLE_COND
# Simbolo recebido:  ) Valor:  ) Posicao: 365
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 365
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', '«']
# Simbolo atual: «
# Simbolo recebido:  « Valor:  « Posicao: 367
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  val1 Posicao: 369
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 369
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 373
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 373
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 373
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  FUNCS_CAST Valor:  PARAVIRNUM Posicao: 375
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'VALUE', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'VALUE', '(', 'FUNCS_CAST']
# Simbolo atual: FUNCS_CAST
# Simbolo recebido:  FUNCS_CAST Valor:  PARAVIRNUM Posicao: 375
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'VALUE', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 385
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 386
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 386
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  / Posicao: 390
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  / Posicao: 390
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 391
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 391
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 394
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 394
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 394
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 395
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  ID Valor:  qtd Posicao: 397
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 397
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', 'DECL']
# Simbolo atual: DECL
# Simbolo recebido:  : Valor:  : Posicao: 400
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'ATRIB']
# Simbolo atual: ATRIB
# Simbolo recebido:  : Valor:  : Posicao: 400
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE', ':']
# Simbolo atual: :
# Simbolo recebido:  : Valor:  : Posicao: 400
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 402
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 402
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  - Posicao: 406
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE', 'OPER_ARIT']
# Simbolo atual: OPER_ARIT
# Simbolo recebido:  OPER_ARIT Valor:  - Posicao: 406
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  NUM Valor:  1 Posicao: 408
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT', 'NUM']
# Simbolo atual: NUM
# Simbolo recebido:  NUM Valor:  1 Posicao: 408
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 409
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ; Valor:  ; Posicao: 409
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 409
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  » Valor:  » Posicao: 411
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', '»']
# Simbolo atual: »
# Simbolo recebido:  » Valor:  » Posicao: 411
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  IMPRIMIR Valor:  IMPRIMIR Posicao: 413
#
# Adicionada a Pilha: ['$', 'MAIN', '»']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', '(']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', '(', 'IMPRIMIR']
# Simbolo atual: IMPRIMIR
# Simbolo recebido:  IMPRIMIR Valor:  IMPRIMIR Posicao: 413
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', '(']
# Simbolo atual: (
# Simbolo recebido:  ( Valor:  ( Posicao: 421
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  PAL Valor:  "QTD" Posicao: 422
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT', 'PAL']
# Simbolo atual: PAL
# Simbolo recebido:  PAL Valor:  "QTD" Posicao: 422
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  , Valor:  , Posicao: 427
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Simbolo atual: MULTIPLE_PARAM
# Simbolo recebido:  , Valor:  , Posicao: 427
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', ',']
# Simbolo atual: ,
# Simbolo recebido:  , Valor:  , Posicao: 427
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  qtd Posicao: 429
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  qtd Posicao: 429
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  , Valor:  , Posicao: 432
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Simbolo atual: MULTIPLE_PARAM
# Simbolo recebido:  , Valor:  , Posicao: 432
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', ',']
# Simbolo atual: ,
# Simbolo recebido:  , Valor:  , Posicao: 432
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 435
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 435
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  , Valor:  , Posicao: 440
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Simbolo atual: MULTIPLE_PARAM
# Simbolo recebido:  , Valor:  , Posicao: 440
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE', ',']
# Simbolo atual: ,
# Simbolo recebido:  , Valor:  , Posicao: 440
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'VALUE']
# Simbolo atual: VALUE
# Simbolo recebido:  ID Valor:  val1 Posicao: 442
#
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Adicionada a Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT', 'ID']
# Simbolo atual: ID
# Simbolo recebido:  ID Valor:  val1 Posicao: 442
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM', 'MULTIPLE_ARIT']
# Simbolo atual: MULTIPLE_ARIT
# Simbolo recebido:  ) Valor:  ) Posicao: 446
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')', 'MULTIPLE_PARAM']
# Simbolo atual: MULTIPLE_PARAM
# Simbolo recebido:  ) Valor:  ) Posicao: 446
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';', ')']
# Simbolo atual: )
# Simbolo recebido:  ) Valor:  ) Posicao: 446
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN', ';']
# Simbolo atual: ;
# Simbolo recebido:  ; Valor:  ; Posicao: 447
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN', '»', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  » Valor:  » Posicao: 449
#
# Caiu em Epson, recuperação
#
# Pilha: ['$', 'MAIN', '»']
# Simbolo atual: »
# Simbolo recebido:  » Valor:  » Posicao: 449
#
# Encontrou o simbolo!
# Pilha: ['$', 'MAIN']
# Simbolo atual: MAIN
# Simbolo recebido:  $ Valor:  $ Posicao: 452
#
# Caiu em Epson, recuperação
#
# Pilha: ['$']
# Simbolo atual: $
# Simbolo recebido:  $ Valor:  $ Posicao: 452
#
# Encontrou o simbolo!
#
#
# Este código é valido!
